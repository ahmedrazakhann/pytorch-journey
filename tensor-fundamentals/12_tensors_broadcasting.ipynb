# %%
import torch
print("Gpu enabled: ", torch.cuda.is_available())
# Out:
# Gpu enabled:  True

# %%
# broadcasting works in pytorch on arithmetic (element-wise operations) only with few rules.
# 1. move low dimensions shape to the  right side and it should match the left side dimension above it, then remaining left side dimension would become equal to 1 and it can compute the result

# broadcasting only works on element-wise operations.

tensor_1 = torch.randint(1,10, (2,2,3,4))
tensor_2 = torch.randint(1,10, (4,))
print(tensor_1.ndim)
print(tensor_1)
# print(tensor_2)

# print(tensor_1 + tensor_2)

tensor = torch.randint(1,10,(1,3,3))
print(tensor.ndim)
print(tensor)
# Out:
# 4
# tensor([[[[2, 7, 1, 1],
#           [1, 4, 4, 7],
#           [9, 7, 2, 8]],
#
#          [[7, 7, 6, 2],
#           [3, 6, 8, 2],
#           [8, 1, 6, 5]]],
#
#
#         [[[7, 3, 6, 3],
#           [7, 6, 8, 7],
#           [6, 2, 8, 3]],
#
#          [[3, 9, 5, 4],
#           [6, 9, 6, 7],
#           [2, 3, 5, 2]]]])
# 3
# tensor([[[8, 6, 2],
#          [3, 8, 2],
#          [1, 5, 7]]])

# %%
vect1 = torch.tensor([2,3])
vect2 = torch.tensor([3,4])

vect1 @ vect2
# Out:
# tensor(18)
