# %%
import torch
print("Gpu enabled: " , torch.cuda.is_available())
# Out:
# Gpu enabled:  False

# %%
x = torch.randint(0,10,(2,3,2))
print(x)
print(x.shape)
y = x.unsqueeze(3) # add dimensions
z= y
# print(y)
# print(y.shape)

print(z.squeeze(3)) # reduce dimensions
# Out:
# tensor([[[2, 9],
#          [9, 3],
#          [2, 5]],
#
#         [[0, 9],
#          [4, 0],
#          [3, 2]]])
# torch.Size([2, 3, 2])
# tensor([[[2, 9],
#          [9, 3],
#          [2, 5]],
#
#         [[0, 9],
#          [4, 0],
#          [3, 2]]])
