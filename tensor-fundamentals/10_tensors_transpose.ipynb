# %%
import torch
print("Gpu enabled: " , torch.cuda.is_available())
# Out:
# Gpu enabled:  True

# %%
my_tensor = torch.arange(1,46).reshape(3,3,5)
print(my_tensor)
print(my_tensor.shape)
my_tensor_1 = my_tensor.permute(2,1,0)
print(my_tensor_1)
my_tensor_1[0]

# Dimension 0 = 2 blocks
# Dimension 1 = 2 rows
# Dimension 2 = 5 columns

# Old shape

# (Block, Row, Column)
# ↓
# (Column, Block, Row)
# Out:
# tensor([[[ 1, 16, 31],
#          [ 6, 21, 36],
#          [11, 26, 41]],
#
#         [[ 2, 17, 32],
#          [ 7, 22, 37],
#          [12, 27, 42]],
#
#         [[ 3, 18, 33],
#          [ 8, 23, 38],
#          [13, 28, 43]],
#
#         [[ 4, 19, 34],
#          [ 9, 24, 39],
#          [14, 29, 44]],
#
#         [[ 5, 20, 35],
#          [10, 25, 40],
#          [15, 30, 45]]])
# tensor([[ 1, 16, 31],
#         [ 6, 21, 36],
#         [11, 26, 41]])
